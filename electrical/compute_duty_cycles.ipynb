# %%
import pandas as pd
df = []
def print_duty_cycles():
        i = 0
        while i <= 100:
            duty_small  = (i-0.0314)/0.0169
            duty_large = (i-0.044)/0.0236
            if duty_small > 100 or duty_large > 100:
                  break
            # print(f"Num:{i}, Duty Cycle Large: {duty_large}, Duty Cycle Small: {duty_small}")
            df.append([i,round(duty_large, 2),round(duty_small, 2)])
            i += 0.05
print_duty_cycles()
df = pd.DataFrame(df)
df.columns = ['Linear Velocity', 'Large Wheel Duty Cycle', 'Small Wheel Duty Cycle']

# %%
pip install pandas
# Out:
# ...
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the '/usr/local/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
df
# Out:
#     Linear Velocity  Large Wheel Duty Cycle  Small Wheel Duty Cycle
# 0              0.00                   -1.86                   -1.86
# 1              0.05                    0.25                    1.10
# 2              0.10                    2.37                    4.06
# 3              0.15                    4.49                    7.02
# 4              0.20                    6.61                    9.98
# 5              0.25                    8.73                   12.93
# 6              0.30                   10.85                   15.89
# 7              0.35                   12.97                   18.85
# 8              0.40                   15.08                   21.81
# 9              0.45                   17.20                   24.77
# 10             0.50                   19.32                   27.73
# 11             0.55                   21.44                   30.69
# 12             0.60                   23.56                   33.64
# ...
